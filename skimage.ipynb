# %%
from skimage import io,img_as_float
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=io.imread('image/rango2.jpg')
img
# Out:
# array([[[106, 136,  74],
#         [106, 136,  74],
#         [106, 136,  74],
#         ...,
#         [109, 139,  79],
#         [108, 138,  78],
#         [108, 138,  78]],
#
#        [[106, 136,  74],
#         [106, 136,  74],
#         [106, 136,  74],
#         ...,
#         [109, 139,  79],
#         [108, 138,  78],
#         [108, 138,  78]],
#
#        [[106, 136,  74],
#         [106, 136,  74],
#         [106, 136,  74],
#         ...,
#         [109, 139,  77],
#         [109, 139,  79],
#         [109, 139,  79]],
#
#        ...,
#
#        [[107, 137,  75],
#         [108, 138,  76],
#         [108, 138,  76],
#         ...,
#         [111, 141,  77],
#         [111, 141,  79],
#         [111, 141,  79]],
#
#        [[107, 137,  75],
#         [107, 137,  75],
#         [108, 138,  76],
#         ...,
#         [111, 141,  77],
#         [111, 141,  79],
#         [111, 141,  79]],
#
#        [[107, 137,  75],
#         [107, 137,  75],
#         [107, 137,  75],
# ...

# %%
img2=img_as_float(img)
img2
# Out:
# array([[[0.41568627, 0.53333333, 0.29019608],
#         [0.41568627, 0.53333333, 0.29019608],
#         [0.41568627, 0.53333333, 0.29019608],
#         ...,
#         [0.42745098, 0.54509804, 0.30980392],
#         [0.42352941, 0.54117647, 0.30588235],
#         [0.42352941, 0.54117647, 0.30588235]],
#
#        [[0.41568627, 0.53333333, 0.29019608],
#         [0.41568627, 0.53333333, 0.29019608],
#         [0.41568627, 0.53333333, 0.29019608],
#         ...,
#         [0.42745098, 0.54509804, 0.30980392],
#         [0.42352941, 0.54117647, 0.30588235],
#         [0.42352941, 0.54117647, 0.30588235]],
#
#        [[0.41568627, 0.53333333, 0.29019608],
#         [0.41568627, 0.53333333, 0.29019608],
#         [0.41568627, 0.53333333, 0.29019608],
#         ...,
#         [0.42745098, 0.54509804, 0.30196078],
#         [0.42745098, 0.54509804, 0.30980392],
#         [0.42745098, 0.54509804, 0.30980392]],
#
#        ...,
#
#        [[0.41960784, 0.5372549 , 0.29411765],
# ...
